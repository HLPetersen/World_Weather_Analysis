# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
requests.get(url+"&q=boston").json()['weather'][0]["description"]
# Out:
# 'clear sky'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat=city_weather['coord']['lat']
        city_lon=city_weather['coord']['lon']
        city_max_temp=city_weather['main']['temp_max']
        city_humidity=city_weather['main']['humidity']
        city_cloudiness=city_weather['clouds']['all']
        city_wind=city_weather['wind']['speed']
        city_country=city_weather['sys']['country']
        city_weather_description=city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat":city_lat,
                         "Lng":city_lon,
                         "Max Temp":city_max_temp,
                          "Humidity": city_humidity,
                         "Cloudiness":city_cloudiness,
                         "Wind Speed":city_wind,
                         "Country":city_country,
                         "Current Description":city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ust-koksa
# Processing Record 2 of Set 1 | saldanha
# Processing Record 3 of Set 1 | niksic
# Processing Record 4 of Set 1 | bereda
# Processing Record 5 of Set 1 | bonthe
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | axim
# Processing Record 8 of Set 1 | bushehr
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | wad madani
# Processing Record 12 of Set 1 | fonte boa
# Processing Record 13 of Set 1 | chipata
# Processing Record 14 of Set 1 | saint george
# Processing Record 15 of Set 1 | hambantota
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | kem
# Processing Record 18 of Set 1 | edd
# Processing Record 19 of Set 1 | la tuque
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | dori
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | grindavik
# Processing Record 26 of Set 1 | norrtalje
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | cockburn town
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | salinas
# Processing Record 31 of Set 1 | rawson
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | klaksvik
# Processing Record 34 of Set 1 | kresttsy
# Processing Record 35 of Set 1 | shatrovo
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | varhaug
# Processing Record 38 of Set 1 | bella union
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | narsaq
# Processing Record 42 of Set 1 | ferrol
# Processing Record 43 of Set 1 | alcudia
# Processing Record 44 of Set 1 | salihorsk
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | marawi
# Processing Record 47 of Set 1 | mehamn
# Processing Record 48 of Set 1 | codrington
# Processing Record 49 of Set 1 | sorland
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | usak
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | caravelas
# Processing Record 4 of Set 2 | sokolo
# Processing Record 5 of Set 2 | bentiu
# Processing Record 6 of Set 2 | razam
# Processing Record 7 of Set 2 | rincon
# Processing Record 8 of Set 2 | burica
# City not found. Skipping...
# Processing Record 9 of Set 2 | paamiut
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | verkhnyaya inta
# Processing Record 12 of Set 2 | lieksa
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | camacha
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | krasnogvardeyskoye
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | bolkhov
# Processing Record 19 of Set 2 | salalah
# Processing Record 20 of Set 2 | tukan
# Processing Record 21 of Set 2 | peniche
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | agadez
# Processing Record 24 of Set 2 | seminole
# Processing Record 25 of Set 2 | bondo
# Processing Record 26 of Set 2 | saint-pierre
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | bandarbeyla
# Processing Record 29 of Set 2 | la plata
# Processing Record 30 of Set 2 | vardo
# Processing Record 31 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | bengkulu
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | cidreira
# Processing Record 36 of Set 2 | yuzhnouralsk
# Processing Record 37 of Set 2 | palmeiras de goias
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | mafinga
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | kruisfontein
# Processing Record 44 of Set 2 | cayenne
# Processing Record 45 of Set 2 | senanga
# Processing Record 46 of Set 2 | baryatino
# Processing Record 47 of Set 2 | boende
# Processing Record 48 of Set 2 | nuuk
# Processing Record 49 of Set 2 | iqaluit
# Processing Record 50 of Set 2 | snasa
# Processing Record 1 of Set 3 | kariba
# Processing Record 2 of Set 3 | bueu
# Processing Record 3 of Set 3 | walvis bay
# Processing Record 4 of Set 3 | hornepayne
# Processing Record 5 of Set 3 | nashville
# Processing Record 6 of Set 3 | alingsas
# Processing Record 7 of Set 3 | dhidhdhoo
# Processing Record 8 of Set 3 | corozal
# Processing Record 9 of Set 3 | tahta
# Processing Record 10 of Set 3 | camocim
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | diamantino
# Processing Record 13 of Set 3 | necochea
# Processing Record 14 of Set 3 | puerto el triunfo
# Processing Record 15 of Set 3 | pangnirtung
# Processing Record 16 of Set 3 | tarata
# Processing Record 17 of Set 3 | atar
# Processing Record 18 of Set 3 | mandiana
# Processing Record 19 of Set 3 | antalaha
# Processing Record 20 of Set 3 | bay roberts
# Processing Record 21 of Set 3 | diego de almagro
# Processing Record 22 of Set 3 | krasnoselkup
# Processing Record 23 of Set 3 | san carlos de bariloche
# Processing Record 24 of Set 3 | voineasa
# Processing Record 25 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 3 | colares
# Processing Record 28 of Set 3 | tawnat
# City not found. Skipping...
# Processing Record 29 of Set 3 | arlit
# Processing Record 30 of Set 3 | asfi
# Processing Record 31 of Set 3 | namibe
# Processing Record 32 of Set 3 | nanortalik
# Processing Record 33 of Set 3 | berlevag
# Processing Record 34 of Set 3 | bukama
# Processing Record 35 of Set 3 | curitibanos
# Processing Record 36 of Set 3 | vila velha
# Processing Record 37 of Set 3 | padang
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 40 of Set 3 | varzea da palma
# Processing Record 41 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 3 | kavaratti
# Processing Record 43 of Set 3 | kathmandu
# Processing Record 44 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 3 | kutum
# Processing Record 47 of Set 3 | dagana
# Processing Record 48 of Set 3 | nueva loja
# Processing Record 49 of Set 3 | baie-comeau
# Processing Record 50 of Set 3 | banyo
# Processing Record 1 of Set 4 | sao joao da barra
# Processing Record 2 of Set 4 | inzhavino
# Processing Record 3 of Set 4 | palmas
# Processing Record 4 of Set 4 | eyl
# Processing Record 5 of Set 4 | pedernales
# Processing Record 6 of Set 4 | ilhabela
# Processing Record 7 of Set 4 | laguna
# Processing Record 8 of Set 4 | rocha
# Processing Record 9 of Set 4 | marovoay
# Processing Record 10 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 4 | altamira
# Processing Record 12 of Set 4 | uglich
# Processing Record 13 of Set 4 | ostrovnoy
# Processing Record 14 of Set 4 | ilulissat
# Processing Record 15 of Set 4 | coquimbo
# Processing Record 16 of Set 4 | gap
# Processing Record 17 of Set 4 | qaqortoq
# Processing Record 18 of Set 4 | mahajanga
# Processing Record 19 of Set 4 | hamilton
# Processing Record 20 of Set 4 | henties bay
# Processing Record 21 of Set 4 | barmer
# Processing Record 22 of Set 4 | ampanihy
# Processing Record 23 of Set 4 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 24 of Set 4 | upernavik
# Processing Record 25 of Set 4 | taoudenni
# Processing Record 26 of Set 4 | springfield
# Processing Record 27 of Set 4 | plettenberg bay
# Processing Record 28 of Set 4 | port shepstone
# Processing Record 29 of Set 4 | olafsvik
# Processing Record 30 of Set 4 | menongue
# Processing Record 31 of Set 4 | saint anthony
# Processing Record 32 of Set 4 | puerto suarez
# Processing Record 33 of Set 4 | felipe carrillo puerto
# Processing Record 34 of Set 4 | rio grande
# Processing Record 35 of Set 4 | victoria
# Processing Record 36 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 4 | frederico westphalen
# Processing Record 38 of Set 4 | kudahuvadhoo
# Processing Record 39 of Set 4 | luanda
# Processing Record 40 of Set 4 | zambezi
# Processing Record 41 of Set 4 | hithadhoo
# Processing Record 42 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 43 of Set 4 | valparaiso
# Processing Record 44 of Set 4 | bajil
# Processing Record 45 of Set 4 | mehran
# Processing Record 46 of Set 4 | campos altos
# Processing Record 47 of Set 4 | maceio
# Processing Record 48 of Set 4 | benghazi
# Processing Record 49 of Set 4 | orje
# Processing Record 50 of Set 4 | riyadh
# Processing Record 1 of Set 5 | villa maria
# Processing Record 2 of Set 5 | puerto del rosario
# Processing Record 3 of Set 5 | warri
# Processing Record 4 of Set 5 | mporokoso
# Processing Record 5 of Set 5 | ponta do sol
# Processing Record 6 of Set 5 | jijiga
# Processing Record 7 of Set 5 | vila franca do campo
# Processing Record 8 of Set 5 | bell ville
# Processing Record 9 of Set 5 | linden
# Processing Record 10 of Set 5 | semenivka
# Processing Record 11 of Set 5 | rognan
# Processing Record 12 of Set 5 | opuwo
# Processing Record 13 of Set 5 | mutata
# Processing Record 14 of Set 5 | iracoubo
# Processing Record 15 of Set 5 | tessalit
# Processing Record 16 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 5 | westport
# Processing Record 18 of Set 5 | coro
# Processing Record 19 of Set 5 | sao filipe
# Processing Record 20 of Set 5 | vazante
# Processing Record 21 of Set 5 | nizwa
# Processing Record 22 of Set 5 | arraial do cabo
# Processing Record 23 of Set 5 | port-cartier
# Processing Record 24 of Set 5 | cartagena
# Processing Record 25 of Set 5 | acarau
# Processing Record 26 of Set 5 | nizhniy baskunchak
# Processing Record 27 of Set 5 | geraldton
# Processing Record 28 of Set 5 | meulaboh
# Processing Record 29 of Set 5 | gouyave
# Processing Record 30 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 5 | parrita
# Processing Record 32 of Set 5 | mendoza
# Processing Record 33 of Set 5 | wattegama
# Processing Record 34 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 35 of Set 5 | kiruna
# Processing Record 36 of Set 5 | paracuru
# Processing Record 37 of Set 5 | uruzgan
# Processing Record 38 of Set 5 | chirongui
# Processing Record 39 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 40 of Set 5 | visnes
# Processing Record 41 of Set 5 | boden
# Processing Record 42 of Set 5 | alta floresta
# Processing Record 43 of Set 5 | cedartown
# Processing Record 44 of Set 5 | kesova gora
# Processing Record 45 of Set 5 | lebu
# Processing Record 46 of Set 5 | newport
# Processing Record 47 of Set 5 | vryburg
# Processing Record 48 of Set 5 | lamu
# Processing Record 49 of Set 5 | santa maria
# Processing Record 50 of Set 5 | hofn
# Processing Record 1 of Set 6 | kolondieba
# Processing Record 2 of Set 6 | praia da vitoria
# Processing Record 3 of Set 6 | matara
# Processing Record 4 of Set 6 | clyde river
# Processing Record 5 of Set 6 | warrington
# Processing Record 6 of Set 6 | rio gallegos
# Processing Record 7 of Set 6 | matagami
# Processing Record 8 of Set 6 | santa cruz
# Processing Record 9 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 10 of Set 6 | haradok
# Processing Record 11 of Set 6 | porvoo
# Processing Record 12 of Set 6 | honningsvag
# Processing Record 13 of Set 6 | husavik
# Processing Record 14 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 6 | san luis
# Processing Record 16 of Set 6 | dire dawa
# Processing Record 17 of Set 6 | sao jose da coroa grande
# Processing Record 18 of Set 6 | chimala
# Processing Record 19 of Set 6 | brest
# Processing Record 20 of Set 6 | constantine
# Processing Record 21 of Set 6 | kuytun
# Processing Record 22 of Set 6 | khuzdar
# Processing Record 23 of Set 6 | granville
# Processing Record 24 of Set 6 | strezhevoy
# Processing Record 25 of Set 6 | tabuk
# Processing Record 26 of Set 6 | banepa
# Processing Record 27 of Set 6 | samfya
# Processing Record 28 of Set 6 | faya
# Processing Record 29 of Set 6 | nesna
# Processing Record 30 of Set 6 | longyearbyen
# Processing Record 31 of Set 6 | kushmurun
# Processing Record 32 of Set 6 | soyo
# Processing Record 33 of Set 6 | zabid
# Processing Record 34 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 6 | mezen
# Processing Record 36 of Set 6 | point pleasant
# Processing Record 37 of Set 6 | san ramon
# Processing Record 38 of Set 6 | colonial heights
# Processing Record 39 of Set 6 | hobyo
# Processing Record 40 of Set 6 | banes
# Processing Record 41 of Set 6 | chichli
# Processing Record 42 of Set 6 | road town
# Processing Record 43 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 6 | talara
# Processing Record 45 of Set 6 | urazovo
# Processing Record 46 of Set 6 | al
# City not found. Skipping...
# Processing Record 47 of Set 6 | nueve de julio
# Processing Record 48 of Set 6 | saint-louis
# Processing Record 49 of Set 6 | trincomalee
# Processing Record 50 of Set 6 | abnub
# Processing Record 1 of Set 7 | arbazh
# Processing Record 2 of Set 7 | wilmington
# Processing Record 3 of Set 7 | vestmannaeyjar
# Processing Record 4 of Set 7 | sinnamary
# Processing Record 5 of Set 7 | takoradi
# Processing Record 6 of Set 7 | balurghat
# Processing Record 7 of Set 7 | cumana
# Processing Record 8 of Set 7 | ostersund
# Processing Record 9 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 10 of Set 7 | semey
# Processing Record 11 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 12 of Set 7 | slavonice
# Processing Record 13 of Set 7 | pusad
# Processing Record 14 of Set 7 | novo aripuana
# Processing Record 15 of Set 7 | omboue
# Processing Record 16 of Set 7 | natal
# Processing Record 17 of Set 7 | yabrud
# Processing Record 18 of Set 7 | san ignacio
# Processing Record 19 of Set 7 | manavalakurichi
# Processing Record 20 of Set 7 | bud
# Processing Record 21 of Set 7 | denizli
# Processing Record 22 of Set 7 | virarajendrapet
# Processing Record 23 of Set 7 | awjilah
# Processing Record 24 of Set 7 | san cristobal
# Processing Record 25 of Set 7 | solaro
# Processing Record 26 of Set 7 | rabo de peixe
# Processing Record 27 of Set 7 | novaya ladoga
# Processing Record 28 of Set 7 | dudinka
# Processing Record 29 of Set 7 | doha
# Processing Record 30 of Set 7 | the valley
# Processing Record 31 of Set 7 | marathon
# Processing Record 32 of Set 7 | sarahan
# Processing Record 33 of Set 7 | cap malheureux
# Processing Record 34 of Set 7 | amapa
# Processing Record 35 of Set 7 | cururupu
# Processing Record 36 of Set 7 | muros
# Processing Record 37 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 7 | huarmey
# Processing Record 39 of Set 7 | korla
# Processing Record 40 of Set 7 | clarence town
# Processing Record 41 of Set 7 | margate
# Processing Record 42 of Set 7 | port-gentil
# Processing Record 43 of Set 7 | lizzano
# Processing Record 44 of Set 7 | jibuti
# Processing Record 45 of Set 7 | severnyy
# Processing Record 46 of Set 7 | raudeberg
# Processing Record 47 of Set 7 | gayeri
# Processing Record 48 of Set 7 | mpika
# Processing Record 49 of Set 7 | stornoway
# Processing Record 50 of Set 7 | moyale
# Processing Record 1 of Set 8 | upington
# Processing Record 2 of Set 8 | royan
# Processing Record 3 of Set 8 | petropavlovskoye
# Processing Record 4 of Set 8 | yar-sale
# Processing Record 5 of Set 8 | angoche
# Processing Record 6 of Set 8 | kulykivka
# Processing Record 7 of Set 8 | rio cuarto
# Processing Record 8 of Set 8 | kaka
# Processing Record 9 of Set 8 | gravdal
# Processing Record 10 of Set 8 | akhmim
# Processing Record 11 of Set 8 | havre-saint-pierre
# Processing Record 12 of Set 8 | bartica
# Processing Record 13 of Set 8 | paytug
# City not found. Skipping...
# Processing Record 14 of Set 8 | moose factory
# Processing Record 15 of Set 8 | maarianhamina
# Processing Record 16 of Set 8 | braslav
# City not found. Skipping...
# Processing Record 17 of Set 8 | svetlogorsk
# Processing Record 18 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 8 | rabak
# Processing Record 20 of Set 8 | santa cruz de tenerife
# Processing Record 21 of Set 8 | pisco
# Processing Record 22 of Set 8 | saint-augustin
# Processing Record 23 of Set 8 | artigas
# Processing Record 24 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 8 | tazmalt
# Processing Record 26 of Set 8 | touros
# Processing Record 27 of Set 8 | betare oya
# Processing Record 28 of Set 8 | tigre
# Processing Record 29 of Set 8 | presidencia roque saenz pena
# Processing Record 30 of Set 8 | chilca
# Processing Record 31 of Set 8 | uniontown
# Processing Record 32 of Set 8 | taywarah
# Processing Record 33 of Set 8 | thunder bay
# Processing Record 34 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 8 | olinda
# Processing Record 36 of Set 8 | moissala
# Processing Record 37 of Set 8 | conceicao do araguaia
# Processing Record 38 of Set 8 | antsohihy
# Processing Record 39 of Set 8 | petauke
# Processing Record 40 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 41 of Set 8 | bonavista
# Processing Record 42 of Set 8 | bilma
# Processing Record 43 of Set 8 | roncesvalles
# Processing Record 44 of Set 8 | kikwit
# Processing Record 45 of Set 8 | thompson
# Processing Record 46 of Set 8 | monrovia
# Processing Record 47 of Set 8 | svetlyy
# Processing Record 48 of Set 8 | hatillo
# Processing Record 49 of Set 8 | richards bay
# Processing Record 50 of Set 8 | cabedelo
# Processing Record 1 of Set 9 | bria
# Processing Record 2 of Set 9 | barentu
# Processing Record 3 of Set 9 | tiznit
# Processing Record 4 of Set 9 | banposh
# Processing Record 5 of Set 9 | san joaquin
# Processing Record 6 of Set 9 | longonjo
# Processing Record 7 of Set 9 | bangalore
# Processing Record 8 of Set 9 | seydi
# Processing Record 9 of Set 9 | mahibadhoo
# Processing Record 10 of Set 9 | zamberk
# Processing Record 11 of Set 9 | san carlos
# Processing Record 12 of Set 9 | aksu
# Processing Record 13 of Set 9 | upata
# Processing Record 14 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 9 | belousovka
# Processing Record 16 of Set 9 | high wycombe
# Processing Record 17 of Set 9 | oktyabrskoye
# Processing Record 18 of Set 9 | koslan
# Processing Record 19 of Set 9 | patos de minas
# Processing Record 20 of Set 9 | cefalu
# Processing Record 21 of Set 9 | batangafo
# Processing Record 22 of Set 9 | betsiamites
# Processing Record 23 of Set 9 | chicama
# Processing Record 24 of Set 9 | altay
# Processing Record 25 of Set 9 | conceicao da barra
# Processing Record 26 of Set 9 | itarema
# Processing Record 27 of Set 9 | kovur
# Processing Record 28 of Set 9 | bardiyah
# Processing Record 29 of Set 9 | vihari
# Processing Record 30 of Set 9 | kidal
# Processing Record 31 of Set 9 | mandera
# Processing Record 32 of Set 9 | nuevo imperial
# Processing Record 33 of Set 9 | genc
# Processing Record 34 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 35 of Set 9 | skerries
# Processing Record 36 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 9 | esperantina
# Processing Record 38 of Set 9 | dneprovskaya
# Processing Record 39 of Set 9 | coihaique
# Processing Record 40 of Set 9 | bani
# Processing Record 41 of Set 9 | ostashkov
# Processing Record 42 of Set 9 | araouane
# Processing Record 43 of Set 9 | mao
# Processing Record 44 of Set 9 | freetown
# Processing Record 45 of Set 9 | grand gaube
# Processing Record 46 of Set 9 | bergen
# Processing Record 47 of Set 9 | lagos
# Processing Record 48 of Set 9 | masallatah
# Processing Record 49 of Set 9 | el prat de llobregat
# Processing Record 50 of Set 9 | acari
# Processing Record 1 of Set 10 | aswan
# Processing Record 2 of Set 10 | uyovu
# Processing Record 3 of Set 10 | derzhavinsk
# Processing Record 4 of Set 10 | tortoli
# Processing Record 5 of Set 10 | torzhok
# Processing Record 6 of Set 10 | kot putli
# City not found. Skipping...
# Processing Record 7 of Set 10 | wiwili
# Processing Record 8 of Set 10 | jumla
# Processing Record 9 of Set 10 | gaoual
# Processing Record 10 of Set 10 | syracuse
# Processing Record 11 of Set 10 | konongo
# Processing Record 12 of Set 10 | maragogi
# Processing Record 13 of Set 10 | mosquera
# Processing Record 14 of Set 10 | lerwick
# Processing Record 15 of Set 10 | ulze
# City not found. Skipping...
# Processing Record 16 of Set 10 | ponta delgada
# Processing Record 17 of Set 10 | valdosta
# Processing Record 18 of Set 10 | kamenolomni
# Processing Record 19 of Set 10 | brigantine
# Processing Record 20 of Set 10 | doka
# Processing Record 21 of Set 10 | bathsheba
# Processing Record 22 of Set 10 | aktau
# Processing Record 23 of Set 10 | camana
# Processing Record 24 of Set 10 | shieli
# Processing Record 25 of Set 10 | santa rosa
# Processing Record 26 of Set 10 | bafoulabe
# Processing Record 27 of Set 10 | nurota
# Processing Record 28 of Set 10 | tevriz
# Processing Record 29 of Set 10 | tome-acu
# City not found. Skipping...
# Processing Record 30 of Set 10 | yantarnyy
# Processing Record 31 of Set 10 | cubarral
# Processing Record 32 of Set 10 | manoel urbano
# Processing Record 33 of Set 10 | passira
# Processing Record 34 of Set 10 | izhmorskiy
# Processing Record 35 of Set 10 | gerede
# Processing Record 36 of Set 10 | araguacu
# Processing Record 37 of Set 10 | belmonte
# Processing Record 38 of Set 10 | shahreza
# Processing Record 39 of Set 10 | taltal
# Processing Record 40 of Set 10 | chandur bazar
# Processing Record 41 of Set 10 | synya
# Processing Record 42 of Set 10 | tutin
# Processing Record 43 of Set 10 | kahramanmaras
# Processing Record 44 of Set 10 | saint-georges
# Processing Record 45 of Set 10 | mount darwin
# Processing Record 46 of Set 10 | san rafael
# Processing Record 47 of Set 10 | malakal
# Processing Record 48 of Set 10 | sinjar
# Processing Record 49 of Set 10 | dunmore town
# Processing Record 50 of Set 10 | gat
# Processing Record 1 of Set 11 | campoverde
# Processing Record 2 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 11 | kasungu
# Processing Record 4 of Set 11 | mykolayivka
# Processing Record 5 of Set 11 | leshukonskoye
# Processing Record 6 of Set 11 | fatehpur
# Processing Record 7 of Set 11 | serenje
# Processing Record 8 of Set 11 | namanyere
# Processing Record 9 of Set 11 | lima
# Processing Record 10 of Set 11 | palafrugell
# Processing Record 11 of Set 11 | avanigadda
# Processing Record 12 of Set 11 | shadegan
# Processing Record 13 of Set 11 | urcos
# Processing Record 14 of Set 11 | port blair
# Processing Record 15 of Set 11 | punta gorda
# Processing Record 16 of Set 11 | birao
# Processing Record 17 of Set 11 | mpongwe
# Processing Record 18 of Set 11 | dimona
# Processing Record 19 of Set 11 | muisne
# Processing Record 20 of Set 11 | nadvoitsy
# Processing Record 21 of Set 11 | torres
# Processing Record 22 of Set 11 | najran
# Processing Record 23 of Set 11 | kastrakion
# Processing Record 24 of Set 11 | eseka
# Processing Record 25 of Set 11 | yarada
# Processing Record 26 of Set 11 | dalhousie
# Processing Record 27 of Set 11 | mutoko
# Processing Record 28 of Set 11 | lucapa
# Processing Record 29 of Set 11 | pokhara
# Processing Record 30 of Set 11 | maldonado
# Processing Record 31 of Set 11 | jalingo
# Processing Record 32 of Set 11 | alekseyevka
# Processing Record 33 of Set 11 | sao felix do xingu
# Processing Record 34 of Set 11 | serov
# Processing Record 35 of Set 11 | komsomolets
# Processing Record 36 of Set 11 | praia
# Processing Record 37 of Set 11 | milos
# Processing Record 38 of Set 11 | tambopata
# Processing Record 39 of Set 11 | ulagan
# Processing Record 40 of Set 11 | manono
# Processing Record 41 of Set 11 | porto belo
# Processing Record 42 of Set 11 | zlobin
# Processing Record 43 of Set 11 | bara
# Processing Record 44 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 45 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 46 of Set 11 | swiecie
# Processing Record 47 of Set 11 | chapais
# Processing Record 48 of Set 11 | liniere
# City not found. Skipping...
# Processing Record 49 of Set 11 | challans
# Processing Record 50 of Set 11 | mana
# Processing Record 1 of Set 12 | berberati
# Processing Record 2 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 12 | igarka
# Processing Record 4 of Set 12 | virtsu
# Processing Record 5 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 6 of Set 12 | bossangoa
# Processing Record 7 of Set 12 | thurso
# Processing Record 8 of Set 12 | los llanos de aridane
# Processing Record 9 of Set 12 | martina franca
# Processing Record 10 of Set 12 | safakulevo
# Processing Record 11 of Set 12 | naryan-mar
# Processing Record 12 of Set 12 | porbandar
# Processing Record 13 of Set 12 | raga
# Processing Record 14 of Set 12 | bingol
# Processing Record 15 of Set 12 | roald
# Processing Record 16 of Set 12 | paramonga
# Processing Record 17 of Set 12 | goure
# Processing Record 18 of Set 12 | crossville
# Processing Record 19 of Set 12 | finnsnes
# Processing Record 20 of Set 12 | ghansor
# Processing Record 21 of Set 12 | pljevlja
# Processing Record 22 of Set 12 | ndola
# Processing Record 23 of Set 12 | opobo
# City not found. Skipping...
# Processing Record 24 of Set 12 | hammerfest
# Processing Record 25 of Set 12 | moiyabana
# City not found. Skipping...
# Processing Record 26 of Set 12 | shache
# Processing Record 27 of Set 12 | saint-francois
# Processing Record 28 of Set 12 | virginia beach
# Processing Record 29 of Set 12 | keuruu
# Processing Record 30 of Set 12 | comodoro rivadavia
# Processing Record 31 of Set 12 | ijero
# Processing Record 32 of Set 12 | male
# Processing Record 33 of Set 12 | ushtobe
# Processing Record 34 of Set 12 | le marin
# Processing Record 35 of Set 12 | zheleznodorozhnyy
# Processing Record 36 of Set 12 | uzice
# Processing Record 37 of Set 12 | tromso
# Processing Record 38 of Set 12 | ouallam
# Processing Record 39 of Set 12 | san andres
# Processing Record 40 of Set 12 | farafenni
# Processing Record 41 of Set 12 | guane
# Processing Record 42 of Set 12 | pangoa
# Processing Record 43 of Set 12 | kamina
# Processing Record 44 of Set 12 | awbari
# Processing Record 45 of Set 12 | nalut
# Processing Record 46 of Set 12 | bonanza
# Processing Record 47 of Set 12 | mango
# Processing Record 48 of Set 12 | albany
# Processing Record 49 of Set 12 | malkangiri
# Processing Record 50 of Set 12 | kamir
# Processing Record 1 of Set 13 | koungou
# Processing Record 2 of Set 13 | mazagao
# Processing Record 3 of Set 13 | a coruna
# Processing Record 4 of Set 13 | lagunas
# Processing Record 5 of Set 13 | lichinga
# Processing Record 6 of Set 13 | abapo
# Processing Record 7 of Set 13 | teseney
# Processing Record 8 of Set 13 | brzeg
# Processing Record 9 of Set 13 | dakar
# Processing Record 10 of Set 13 | lusambo
# Processing Record 11 of Set 13 | pittsfield
# Processing Record 12 of Set 13 | sassandra
# Processing Record 13 of Set 13 | shurugwi
# Processing Record 14 of Set 13 | bardsir
# Processing Record 15 of Set 13 | martinsville
# Processing Record 16 of Set 13 | hauterive
# Processing Record 17 of Set 13 | khalkhal
# Processing Record 18 of Set 13 | bubaque
# Processing Record 19 of Set 13 | bursol
# City not found. Skipping...
# Processing Record 20 of Set 13 | boyuibe
# Processing Record 21 of Set 13 | krasnyy yar
# Processing Record 22 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 23 of Set 13 | buraydah
# Processing Record 24 of Set 13 | lakshmeshwar
# Processing Record 25 of Set 13 | uyemskiy
# Processing Record 26 of Set 13 | bahia blanca
# Processing Record 27 of Set 13 | waynesboro
# Processing Record 28 of Set 13 | tubuala
# Processing Record 29 of Set 13 | ardahan
# Processing Record 30 of Set 13 | limenaria
# Processing Record 31 of Set 13 | carutapera
# Processing Record 32 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 13 | hainburg
# Processing Record 34 of Set 13 | huayucachi
# Processing Record 35 of Set 13 | awka
# Processing Record 36 of Set 13 | point fortin
# Processing Record 37 of Set 13 | kodino
# Processing Record 38 of Set 13 | castleblayney
# Processing Record 39 of Set 13 | ilebo
# Processing Record 40 of Set 13 | petropavl
# Processing Record 41 of Set 13 | sisimiut
# Processing Record 42 of Set 13 | marrakesh
# Processing Record 43 of Set 13 | plouzane
# Processing Record 44 of Set 13 | skjervoy
# Processing Record 45 of Set 13 | tibacuy
# Processing Record 46 of Set 13 | ugoofaaru
# Processing Record 47 of Set 13 | turukhansk
# Processing Record 48 of Set 13 | kalmunai
# Processing Record 49 of Set 13 | srikakulam
# Processing Record 50 of Set 13 | berbera
# Processing Record 1 of Set 14 | pozoblanco
# Processing Record 2 of Set 14 | svencionys
# Processing Record 3 of Set 14 | puerto pinasco
# City not found. Skipping...
# Processing Record 4 of Set 14 | anzio
# Processing Record 5 of Set 14 | san jose
# Processing Record 6 of Set 14 | novouzensk
# Processing Record 7 of Set 14 | inirida
# Processing Record 8 of Set 14 | kembe
# Processing Record 9 of Set 14 | shelburne
# Processing Record 10 of Set 14 | aksarka
# Processing Record 11 of Set 14 | qasigiannguit
# Processing Record 12 of Set 14 | cravo norte
# Processing Record 13 of Set 14 | maniitsoq
# Processing Record 14 of Set 14 | emba
# Processing Record 15 of Set 14 | lardos
# Processing Record 16 of Set 14 | kirillov
# Processing Record 17 of Set 14 | jay
# Processing Record 18 of Set 14 | phalaborwa
# Processing Record 19 of Set 14 | severodvinsk
# Processing Record 20 of Set 14 | kerman
# Processing Record 21 of Set 14 | sao miguel
# Processing Record 22 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 14 | nouadhibou
# Processing Record 24 of Set 14 | kondoa
# Processing Record 25 of Set 14 | puerto baquerizo moreno
# Processing Record 26 of Set 14 | gorom-gorom
# Processing Record 27 of Set 14 | taquarituba
# Processing Record 28 of Set 14 | ivanishchi
# Processing Record 29 of Set 14 | detva
# Processing Record 30 of Set 14 | glens falls
# Processing Record 31 of Set 14 | cervo
# Processing Record 32 of Set 14 | humaita
# Processing Record 33 of Set 14 | puerto ayora
# Processing Record 34 of Set 14 | surgut
# Processing Record 35 of Set 14 | almeirim
# Processing Record 36 of Set 14 | sinnar
# Processing Record 37 of Set 14 | togur
# Processing Record 38 of Set 14 | boca do acre
# Processing Record 39 of Set 14 | qiryat bialik
# Processing Record 40 of Set 14 | catu
# Processing Record 41 of Set 14 | thinadhoo
# Processing Record 42 of Set 14 | mercedes
# Processing Record 43 of Set 14 | labrea
# Processing Record 44 of Set 14 | bujaru
# Processing Record 45 of Set 14 | derbent
# Processing Record 46 of Set 14 | constitucion
# Processing Record 47 of Set 14 | hassleholm
# Processing Record 48 of Set 14 | novyy buh
# Processing Record 49 of Set 14 | impfondo
# Processing Record 50 of Set 14 | bondoukou
# Processing Record 1 of Set 15 | fort-shevchenko
# Processing Record 2 of Set 15 | goderich
# Processing Record 3 of Set 15 | harper
# Processing Record 4 of Set 15 | lephepe
# City not found. Skipping...
# Processing Record 5 of Set 15 | meybod
# Processing Record 6 of Set 15 | sandviken
# Processing Record 7 of Set 15 | oltina
# Processing Record 8 of Set 15 | gari
# Processing Record 9 of Set 15 | esmeralda
# Processing Record 10 of Set 15 | salinopolis
# Processing Record 11 of Set 15 | machiques
# Processing Record 12 of Set 15 | komatipoort
# Processing Record 13 of Set 15 | kedougou
# Processing Record 14 of Set 15 | izhma
# Processing Record 15 of Set 15 | barra do garcas
# Processing Record 16 of Set 15 | lebyazhye
# Processing Record 17 of Set 15 | inhambane
# Processing Record 18 of Set 15 | ambilobe
# Processing Record 19 of Set 15 | saint marys
# Processing Record 20 of Set 15 | santa rita
# Processing Record 21 of Set 15 | taybad
# Processing Record 22 of Set 15 | saginaw
# Processing Record 23 of Set 15 | lushoto
# Processing Record 24 of Set 15 | kalemie
# Processing Record 25 of Set 15 | nouakchott
# Processing Record 26 of Set 15 | ondjiva
# Processing Record 27 of Set 15 | letlhakeng
# Processing Record 28 of Set 15 | canto do buriti
# Processing Record 29 of Set 15 | freeport
# Processing Record 30 of Set 15 | abatskoye
# Processing Record 31 of Set 15 | glace bay
# Processing Record 32 of Set 15 | mecca
# Processing Record 33 of Set 15 | qafsah
# City not found. Skipping...
# Processing Record 34 of Set 15 | shakiso
# Processing Record 35 of Set 15 | brae
# Processing Record 36 of Set 15 | vorniceni
# Processing Record 37 of Set 15 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 38 of Set 15 | chalus
# Processing Record 39 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 15 | dmitriyevka
# Processing Record 41 of Set 15 | mogadishu
# Processing Record 42 of Set 15 | turbat
# Processing Record 43 of Set 15 | vesoul
# Processing Record 44 of Set 15 | wakefield
# Processing Record 45 of Set 15 | tara
# Processing Record 46 of Set 15 | khowst
# Processing Record 47 of Set 15 | jeremie
# Processing Record 48 of Set 15 | porto santo
# Processing Record 49 of Set 15 | kayes
# Processing Record 50 of Set 15 | volchansk
# Processing Record 1 of Set 16 | talcahuano
# Processing Record 2 of Set 16 | alur
# Processing Record 3 of Set 16 | athmallik
# Processing Record 4 of Set 16 | merke
# Processing Record 5 of Set 16 | benjamin aceval
# Processing Record 6 of Set 16 | ayorou
# Processing Record 7 of Set 16 | ciudad bolivar
# Processing Record 8 of Set 16 | madimba
# Processing Record 9 of Set 16 | quatre cocos
# Processing Record 10 of Set 16 | bandar-e lengeh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 702

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0      Ust-Koksa  50.2696  85.6108      7.45        96         100
# 1       Saldanha -33.0117  17.9442     66.25        88           0
# 2         Niksic  42.7731  18.9445     56.68        99         100
# 3         Bereda  43.2686  -7.5406     43.41       100         100
# 4         Bonthe   7.5264 -12.5050     79.39        79          30
# 5      Mahebourg -20.4081  57.7000     77.29        83          40
# 6           Axim   4.8699  -2.2405     78.13        85           1
# 7        Bushehr  28.9684  50.8385     62.69        59           0
# 8  Mar Del Plata -38.0023 -57.5575     66.22        72           0
# 9      Jamestown  42.0970 -79.2353     29.01        66           0
#
#    Wind Speed Country Current Description
# 0        2.68      RU     overcast clouds
# 1        5.57      ZA           clear sky
# 2        8.70      ME     overcast clouds
# 3        5.08      ES     overcast clouds
# 4        3.98      SL    scattered clouds
# 5        8.05      MU          light rain
# 6        5.10      GH          light rain
# 7       11.50      IR           clear sky
# 8       13.80      AR           clear sky
# 9        9.22      US           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head()
# Out:
#         City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ust-Koksa      RU  50.2696  85.6108      7.45        96         100
# 1   Saldanha      ZA -33.0117  17.9442     66.25        88           0
# 2     Niksic      ME  42.7731  18.9445     56.68        99         100
# 3     Bereda      ES  43.2686  -7.5406     43.41       100         100
# 4     Bonthe      SL   7.5264 -12.5050     79.39        79          30
#
#    Wind Speed Current Description
# 0        2.68     overcast clouds
# 1        5.57           clear sky
# 2        8.70     overcast clouds
# 3        5.08     overcast clouds
# 4        3.98    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
file_name = "C:/Users/heidi/Documents/Projects/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(file_name, index_label="City_ID")
